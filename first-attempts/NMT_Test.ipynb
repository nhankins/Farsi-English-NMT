# %%
# !pip install OpenNMT-py
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 208 kB 30.3 MB/s
# ...
#      |████████████████████████████████| 57 kB 6.5 MB/s
# ...
#      |████████████████████████████████| 118 kB 68.4 MB/s
# ...
#      |████████████████████████████████| 16.9 MB 31.9 MB/s
# ...

# %%
# !onmt_build_vocab -config en_fa_data/config.yaml -n_sample 100000
# Out:
# Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2022-11-14 22:51:09,907 INFO] Counter vocab from 100000 samples.
# [2022-11-14 22:51:09,907 INFO] Build vocab on 100000 transformed examples/corpus.
# [2022-11-14 22:51:11,837 INFO] Counters src:74546
# [2022-11-14 22:51:11,837 INFO] Counters tgt:79451

# %%
# !onmt_train -config en_fa_data/config.yaml
# Out:
# [2022-11-14 22:52:47,516 INFO] Missing transforms field for corpus_1 data, set to default: [].
# [2022-11-14 22:52:47,516 WARNING] Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2022-11-14 22:52:47,516 INFO] Missing transforms field for valid data, set to default: [].
# [2022-11-14 22:52:47,517 INFO] Parsed 2 corpora from -data.
# [2022-11-14 22:52:47,517 INFO] Get special vocabs from Transforms: {'src': set(), 'tgt': set()}.
# [2022-11-14 22:52:47,940 INFO] Building model...
# [2022-11-14 22:52:55,314 INFO] NMTModel(
#   (encoder): RNNEncoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
#         (emb_luts): Elementwise(
#           (0): Embedding(32768, 500, padding_idx=1)
#         )
#       )
#     )
#     (rnn): LSTM(500, 500, num_layers=2, batch_first=True, dropout=0.3)
#   )
#   (decoder): InputFeedRNNDecoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
#         (emb_luts): Elementwise(
# ...

# %%
# !onmt_translate -model en_fa_data/run/model_step_1000.pt -src en_fa_data/fa_test.txt -output en_fa_data/pred_1000.txt -gpu 0 -verbose
# Out:
# Streaming output truncated to the last 5000 lines.
# PRED 45291: <unk> <unk> <unk> <unk> <unk> <unk>
# PRED SCORE: -1.0640
#
# [2022-11-14 23:04:24,523 INFO]
# SENT 45292: None
# PRED 45292: <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk>
# PRED SCORE: -1.2200
#
# [2022-11-14 23:04:24,523 INFO]
# SENT 45293: None
# PRED 45293: <unk> <unk> <unk>
# PRED SCORE: -0.8161
#
# [2022-11-14 23:04:24,523 INFO]
# SENT 45294: None
# PRED 45294: <unk> <unk> <unk>
# PRED SCORE: -0.8470
#
# [2022-11-14 23:04:24,524 INFO]
# SENT 45295: None
# PRED 45295: <unk> <unk> <unk>
# PRED SCORE: -0.7562
#
# [2022-11-14 23:04:24,524 INFO]
# SENT 45296: None
# PRED 45296: <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk>
# PRED SCORE: -1.2058
#
# [2022-11-14 23:04:24,641 INFO]
# SENT 45297: None
# PRED 45297: <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk>
# PRED SCORE: -1.3479
#
# [2022-11-14 23:04:24,641 INFO]
# ...
